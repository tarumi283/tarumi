# %% [markdown]
# <a href="https://colab.research.google.com/github/tarumi283/tarumi/blob/main/3way_ANOVA_Tukey_Kramer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas statsmodels
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (0.14.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.11.4)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels) (1.16.0)

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import MultiComparison

# CSVファイルのパス
csv_file_path = '/content/result2_period.csv'

# CSVファイルの読み込み
data = pd.read_csv(csv_file_path)

# データの確認
print("データの先頭部分:\n", data.head())

# 因子A、因子B、因子Cの名前を適切に設定してください
factorA = 'factorA'  # 因子Aを示す列名
factorB = 'factorB'  # 因子Bを示す列名
factorC = 'factorC'  # 因子Cを示す列名
value_column = 'value'  # 値を示す列名

# 3要因分散分析の実行
formula = f'{value_column} ~ C({factorA}) + C({factorB}) + C({factorC}) + \
            C({factorA}):C({factorB}) + C({factorA}):C({factorC}) + C({factorB}):C({factorC}) + \
            C({factorA}):C({factorB}):C({factorC})'
model = ols(formula, data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print("\n3要因分散分析の結果:\n", anova_table)

# 因子Aに対するTukey-Kramer HSDの実行
mc_A = MultiComparison(data[value_column], data[factorA])
result_A = mc_A.tukeyhsd()
print("\nTukey-Kramer HSDの結果 (因子Aの比較):")
print(result_A)
print(result_A.summary())

# 因子Bに対するTukey-Kramer HSDの実行
mc_B = MultiComparison(data[value_column], data[factorB])
result_B = mc_B.tukeyhsd()
print("\nTukey-Kramer HSDの結果 (因子Bの比較):")
print(result_B)
print(result_B.summary())

# 因子Cに対するTukey-Kramer HSDの実行
mc_C = MultiComparison(data[value_column], data[factorC])
result_C = mc_C.tukeyhsd()
print("\nTukey-Kramer HSDの結果 (因子Cの比較):")
print(result_C)
print(result_C.summary())

# 交互作用効果に対するTukey-Kramer HSD検定のための新しい列を作成
data['interaction_AB'] = data[factorA].astype(str) + ':' + data[factorB].astype(str)
mc_interaction_AB = MultiComparison(data[value_column], data['interaction_AB'])
result_interaction_AB = mc_interaction_AB.tukeyhsd()
print("\nTukey-Kramer HSDの結果 (因子Aと因子Bの交互作用の比較):")
print(result_interaction_AB)
print(result_interaction_AB.summary())

data['interaction_AC'] = data[factorA].astype(str) + ':' + data[factorC].astype(str)
mc_interaction_AC = MultiComparison(data[value_column], data['interaction_AC'])
result_interaction_AC = mc_interaction_AC.tukeyhsd()
print("\nTukey-Kramer HSDの結果 (因子Aと因子Cの交互作用の比較):")
print(result_interaction_AC)
print(result_interaction_AC.summary())

data['interaction_BC'] = data[factorB].astype(str) + ':' + data[factorC].astype(str)
mc_interaction_BC = MultiComparison(data[value_column], data['interaction_BC'])
result_interaction_BC = mc_interaction_BC.tukeyhsd()
print("\nTukey-Kramer HSDの結果 (因子Bと因子Cの交互作用の比較):")
print(result_interaction_BC)
print(result_interaction_BC.summary())

data['interaction_ABC'] = data[factorA].astype(str) + ':' + data[factorB].astype(str) + ':' + data[factorC].astype(str)
mc_interaction_ABC = MultiComparison(data[value_column], data['interaction_ABC'])
result_interaction_ABC = mc_interaction_ABC.tukeyhsd()
print("\nTukey-Kramer HSDの結果 (因子A、因子B、因子Cの交互作用の比較):")
print(result_interaction_ABC)
print(result_interaction_ABC.summary())
# Out:
# データの先頭部分:
#     value factorA factorB   factorC
# 0  1.000    dH2O    DMSO  Negative
# 1  0.995    dH2O    DMSO  Negative
# 2  1.000    dH2O    DMSO  Negative
# 3  0.000    dH2O    DMSO  Positive
# 4  0.005    dH2O    DMSO  Positive
#
# 3要因分散分析の結果:
#                                          sum_sq    df             F  \
# C(factorA)                        9.971201e-31   1.0  7.815090e-28
# C(factorB)                        1.365454e-32   1.0  1.070197e-29
# C(factorC)                        1.967001e+00   1.0  1.541669e+03
# C(factorA):C(factorB)             1.769448e-32   1.0  1.386834e-29
# C(factorA):C(factorC)             1.062264e+00   1.0  8.325662e+02
# C(factorB):C(factorC)             4.471027e-03   1.0  3.504240e+00
# C(factorA):C(factorB):C(factorC)  5.629607e-03   1.0  4.412295e+00
# Residual                          2.041425e-02  16.0           NaN
#
#                                         PR(>F)
# C(factorA)                        1.000000e+00
# C(factorB)                        1.000000e+00
# C(factorC)                        2.444834e-17
# C(factorA):C(factorB)             1.000000e+00
# C(factorA):C(factorC)             3.164051e-15
# C(factorB):C(factorC)             7.960775e-02
# C(factorA):C(factorB):C(factorC)  5.188639e-02
# Residual                                   NaN
#
# Tukey-Kramer HSDの結果 (因子Aの比較):
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================
# group1 group2 meandiff p-adj  lower  upper  reject
# --------------------------------------------------
#    Oxi   dH2O     -0.0   1.0 -0.3157 0.3157  False
# --------------------------------------------------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================
# group1 group2 meandiff p-adj  lower  upper  reject
# --------------------------------------------------
#    Oxi   dH2O     -0.0   1.0 -0.3157 0.3157  False
# --------------------------------------------------
#
# Tukey-Kramer HSDの結果 (因子Bの比較):
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================
# group1 group2 meandiff p-adj  lower  upper  reject
# --------------------------------------------------
#    ABT   DMSO      0.0   1.0 -0.3157 0.3157  False
# --------------------------------------------------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================
# group1 group2 meandiff p-adj  lower  upper  reject
# --------------------------------------------------
#    ABT   DMSO      0.0   1.0 -0.3157 0.3157  False
# --------------------------------------------------
#
# Tukey-Kramer HSDの結果 (因子Cの比較):
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1   group2  meandiff p-adj  lower   upper  reject
# -------------------------------------------------------
# Negative Positive  -0.5726   0.0 -0.7613 -0.3839   True
# -------------------------------------------------------
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1   group2  meandiff p-adj  lower   upper  reject
# -------------------------------------------------------
# Negative Positive  -0.5726   0.0 -0.7613 -0.3839   True
# -------------------------------------------------------
#
# Tukey-Kramer HSDの結果 (因子Aと因子Bの交互作用の比較):
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1    group2  meandiff p-adj  lower  upper  reject
# -------------------------------------------------------
#  Oxi:ABT  Oxi:DMSO      0.0   1.0 -0.6321 0.6321  False
#  Oxi:ABT  dH2O:ABT     -0.0   1.0 -0.6321 0.6321  False
#  Oxi:ABT dH2O:DMSO      0.0   1.0 -0.6321 0.6321  False
# Oxi:DMSO  dH2O:ABT     -0.0   1.0 -0.6321 0.6321  False
# Oxi:DMSO dH2O:DMSO      0.0   1.0 -0.6321 0.6321  False
# dH2O:ABT dH2O:DMSO      0.0   1.0 -0.6321 0.6321  False
# -------------------------------------------------------
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================
#  group1    group2  meandiff p-adj  lower  upper  reject
# -------------------------------------------------------
#  Oxi:ABT  Oxi:DMSO      0.0   1.0 -0.6321 0.6321  False
#  Oxi:ABT  dH2O:ABT     -0.0   1.0 -0.6321 0.6321  False
#  Oxi:ABT dH2O:DMSO      0.0   1.0 -0.6321 0.6321  False
# Oxi:DMSO  dH2O:ABT     -0.0   1.0 -0.6321 0.6321  False
# Oxi:DMSO dH2O:DMSO      0.0   1.0 -0.6321 0.6321  False
# dH2O:ABT dH2O:DMSO      0.0   1.0 -0.6321 0.6321  False
# -------------------------------------------------------
#
# Tukey-Kramer HSDの結果 (因子Aと因子Cの交互作用の比較):
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================
#     group1        group2    meandiff p-adj  lower   upper  reject
# -----------------------------------------------------------------
#  Oxi:Negative  Oxi:Positive  -0.1518   0.0 -0.2149 -0.0887   True
#  Oxi:Negative dH2O:Negative   0.4208   0.0  0.3576  0.4839   True
#  Oxi:Negative dH2O:Positive  -0.5726   0.0 -0.6357 -0.5094   True
#  Oxi:Positive dH2O:Negative   0.5726   0.0  0.5094  0.6357   True
#  Oxi:Positive dH2O:Positive  -0.4208   0.0 -0.4839 -0.3576   True
# dH2O:Negative dH2O:Positive  -0.9933   0.0 -1.0565 -0.9302   True
# -----------------------------------------------------------------
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================
#     group1        group2    meandiff p-adj  lower   upper  reject
# -----------------------------------------------------------------
#  Oxi:Negative  Oxi:Positive  -0.1518   0.0 -0.2149 -0.0887   True
#  Oxi:Negative dH2O:Negative   0.4208   0.0  0.3576  0.4839   True
#  Oxi:Negative dH2O:Positive  -0.5726   0.0 -0.6357 -0.5094   True
#  Oxi:Positive dH2O:Negative   0.5726   0.0  0.5094  0.6357   True
#  Oxi:Positive dH2O:Positive  -0.4208   0.0 -0.4839 -0.3576   True
# dH2O:Negative dH2O:Positive  -0.9933   0.0 -1.0565 -0.9302   True
# -----------------------------------------------------------------
#
# Tukey-Kramer HSDの結果 (因子Bと因子Cの交互作用の比較):
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#     group1        group2    meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------
#  ABT:Negative  ABT:Positive  -0.5999 0.0013 -0.9768 -0.2229   True
#  ABT:Negative DMSO:Negative  -0.0273  0.997 -0.4043  0.3497  False
#  ABT:Negative DMSO:Positive  -0.5726  0.002 -0.9495 -0.1956   True
#  ABT:Positive DMSO:Negative   0.5726  0.002  0.1956  0.9495   True
#  ABT:Positive DMSO:Positive   0.0273  0.997 -0.3497  0.4043  False
# DMSO:Negative DMSO:Positive  -0.5453 0.0032 -0.9222 -0.1683   True
# ------------------------------------------------------------------
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#     group1        group2    meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------
#  ABT:Negative  ABT:Positive  -0.5999 0.0013 -0.9768 -0.2229   True
#  ABT:Negative DMSO:Negative  -0.0273  0.997 -0.4043  0.3497  False
#  ABT:Negative DMSO:Positive  -0.5726  0.002 -0.9495 -0.1956   True
#  ABT:Positive DMSO:Negative   0.5726  0.002  0.1956  0.9495   True
#  ABT:Positive DMSO:Positive   0.0273  0.997 -0.3497  0.4043  False
# DMSO:Negative DMSO:Positive  -0.5453 0.0032 -0.9222 -0.1683   True
# ------------------------------------------------------------------
#
# Tukey-Kramer HSDの結果 (因子A、因子B、因子Cの交互作用の比較):
#             Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================================
#       group1             group2       meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------------------
#   Oxi:ABT:Negative   Oxi:ABT:Positive  -0.2097    0.0 -0.3107 -0.1088   True
#   Oxi:ABT:Negative  Oxi:DMSO:Negative  -0.0579 0.5187 -0.1589   0.043  False
#   Oxi:ABT:Negative  Oxi:DMSO:Positive  -0.1518 0.0017 -0.2528 -0.0508   True
#   Oxi:ABT:Negative  dH2O:ABT:Negative   0.3901    0.0  0.2892  0.4911   True
#   Oxi:ABT:Negative  dH2O:ABT:Positive  -0.5999    0.0 -0.7008 -0.4989   True
#   Oxi:ABT:Negative dH2O:DMSO:Negative   0.3935    0.0  0.2925  0.4944   True
#   Oxi:ABT:Negative dH2O:DMSO:Positive  -0.6032    0.0 -0.7042 -0.5022   True
#   Oxi:ABT:Positive  Oxi:DMSO:Negative   0.1518 0.0017  0.0508  0.2528   True
#   Oxi:ABT:Positive  Oxi:DMSO:Positive   0.0579 0.5187  -0.043  0.1589  False
#   Oxi:ABT:Positive  dH2O:ABT:Negative   0.5999    0.0  0.4989  0.7008   True
#   Oxi:ABT:Positive  dH2O:ABT:Positive  -0.3901    0.0 -0.4911 -0.2892   True
#   Oxi:ABT:Positive dH2O:DMSO:Negative   0.6032    0.0  0.5022  0.7042   True
#   Oxi:ABT:Positive dH2O:DMSO:Positive  -0.3935    0.0 -0.4944 -0.2925   True
#  Oxi:DMSO:Negative  Oxi:DMSO:Positive  -0.0939 0.0784 -0.1948  0.0071  False
#  Oxi:DMSO:Negative  dH2O:ABT:Negative   0.4481    0.0  0.3471   0.549   True
#  Oxi:DMSO:Negative  dH2O:ABT:Positive  -0.5419    0.0 -0.6429  -0.441   True
#  Oxi:DMSO:Negative dH2O:DMSO:Negative   0.4514    0.0  0.3504  0.5524   True
#  Oxi:DMSO:Negative dH2O:DMSO:Positive  -0.5453    0.0 -0.6462 -0.4443   True
#  Oxi:DMSO:Positive  dH2O:ABT:Negative   0.5419    0.0   0.441  0.6429   True
#  Oxi:DMSO:Positive  dH2O:ABT:Positive  -0.4481    0.0  -0.549 -0.3471   True
#  Oxi:DMSO:Positive dH2O:DMSO:Negative   0.5453    0.0  0.4443  0.6462   True
#  Oxi:DMSO:Positive dH2O:DMSO:Positive  -0.4514    0.0 -0.5524 -0.3504   True
#  dH2O:ABT:Negative  dH2O:ABT:Positive    -0.99    0.0  -1.091  -0.889   True
#  dH2O:ABT:Negative dH2O:DMSO:Negative   0.0033    1.0 -0.0976  0.1043  False
#  dH2O:ABT:Negative dH2O:DMSO:Positive  -0.9933    0.0 -1.0943 -0.8924   True
#  dH2O:ABT:Positive dH2O:DMSO:Negative   0.9933    0.0  0.8924  1.0943   True
#  dH2O:ABT:Positive dH2O:DMSO:Positive  -0.0033    1.0 -0.1043  0.0976  False
# dH2O:DMSO:Negative dH2O:DMSO:Positive  -0.9967    0.0 -1.0976 -0.8957   True
# ----------------------------------------------------------------------------
#             Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================================
#       group1             group2       meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------------------
#   Oxi:ABT:Negative   Oxi:ABT:Positive  -0.2097    0.0 -0.3107 -0.1088   True
#   Oxi:ABT:Negative  Oxi:DMSO:Negative  -0.0579 0.5187 -0.1589   0.043  False
#   Oxi:ABT:Negative  Oxi:DMSO:Positive  -0.1518 0.0017 -0.2528 -0.0508   True
#   Oxi:ABT:Negative  dH2O:ABT:Negative   0.3901    0.0  0.2892  0.4911   True
#   Oxi:ABT:Negative  dH2O:ABT:Positive  -0.5999    0.0 -0.7008 -0.4989   True
#   Oxi:ABT:Negative dH2O:DMSO:Negative   0.3935    0.0  0.2925  0.4944   True
#   Oxi:ABT:Negative dH2O:DMSO:Positive  -0.6032    0.0 -0.7042 -0.5022   True
#   Oxi:ABT:Positive  Oxi:DMSO:Negative   0.1518 0.0017  0.0508  0.2528   True
#   Oxi:ABT:Positive  Oxi:DMSO:Positive   0.0579 0.5187  -0.043  0.1589  False
#   Oxi:ABT:Positive  dH2O:ABT:Negative   0.5999    0.0  0.4989  0.7008   True
#   Oxi:ABT:Positive  dH2O:ABT:Positive  -0.3901    0.0 -0.4911 -0.2892   True
#   Oxi:ABT:Positive dH2O:DMSO:Negative   0.6032    0.0  0.5022  0.7042   True
#   Oxi:ABT:Positive dH2O:DMSO:Positive  -0.3935    0.0 -0.4944 -0.2925   True
#  Oxi:DMSO:Negative  Oxi:DMSO:Positive  -0.0939 0.0784 -0.1948  0.0071  False
#  Oxi:DMSO:Negative  dH2O:ABT:Negative   0.4481    0.0  0.3471   0.549   True
#  Oxi:DMSO:Negative  dH2O:ABT:Positive  -0.5419    0.0 -0.6429  -0.441   True
#  Oxi:DMSO:Negative dH2O:DMSO:Negative   0.4514    0.0  0.3504  0.5524   True
#  Oxi:DMSO:Negative dH2O:DMSO:Positive  -0.5453    0.0 -0.6462 -0.4443   True
#  Oxi:DMSO:Positive  dH2O:ABT:Negative   0.5419    0.0   0.441  0.6429   True
#  Oxi:DMSO:Positive  dH2O:ABT:Positive  -0.4481    0.0  -0.549 -0.3471   True
#  Oxi:DMSO:Positive dH2O:DMSO:Negative   0.5453    0.0  0.4443  0.6462   True
#  Oxi:DMSO:Positive dH2O:DMSO:Positive  -0.4514    0.0 -0.5524 -0.3504   True
#  dH2O:ABT:Negative  dH2O:ABT:Positive    -0.99    0.0  -1.091  -0.889   True
#  dH2O:ABT:Negative dH2O:DMSO:Negative   0.0033    1.0 -0.0976  0.1043  False
#  dH2O:ABT:Negative dH2O:DMSO:Positive  -0.9933    0.0 -1.0943 -0.8924   True
#  dH2O:ABT:Positive dH2O:DMSO:Negative   0.9933    0.0  0.8924  1.0943   True
#  dH2O:ABT:Positive dH2O:DMSO:Positive  -0.0033    1.0 -0.1043  0.0976  False
# dH2O:DMSO:Negative dH2O:DMSO:Positive  -0.9967    0.0 -1.0976 -0.8957   True
# ----------------------------------------------------------------------------
